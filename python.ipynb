# %% [markdown]
# <a href="https://colab.research.google.com/github/PatraSnigdhaRani-lab/python_sample_nist/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test

# %%
print("hello")
# Out:
# hello
